# %%
# import libraries
from pathlib import Path
from inflation_forecast.text_pre_process import read_txt

# %%
# define path to minutes and speeches data folders
root_dir = Path.cwd().parent
minutes_dir = Path(str(root_dir) + "/data/minutes")
gov_speech_dir = Path(str(root_dir) + "/data/speeches/gov")
dgov_speech_dir = Path(str(root_dir) + "/data/speeches/dgov")
bm_speech_dir = Path(str(root_dir) + "/data/speeches/bm")

# %%
# read minutes and speeches
minutes = read_txt(minutes_dir)
gov_speech_dir = read_txt(gov_speech_dir)
dgov_speech_dir = read_txt(dgov_speech_dir)
bm_speech_dir = read_txt(bm_speech_dir)
